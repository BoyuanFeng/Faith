# %%
import os

import numpy as np
import tvm
from tvm import te, auto_scheduler

import os
os.environ["CUDA_VISIBLE_DEVICES"]='1' # 0 for A6000 on winnie, 1 for P6000 on winnie.
from tvm.autotvm.measure.measure_methods import set_cuda_target_arch
set_cuda_target_arch('sm_60')

# %%
@auto_scheduler.register_workload  # Note the auto_scheduler decorator
def matmul_add(N, L, M, dtype):
    A = te.placeholder((N, L), name="A", dtype=dtype)
    B = te.placeholder((L, M), name="B", dtype=dtype)
    C = te.placeholder((N, M), name="C", dtype=dtype)

    k = te.reduce_axis((0, L), name="k")
    matmul = te.compute(
        (N, M),
        lambda i, j: te.sum(A[i, k] * B[k, j], axis=k),
        name="matmul",
        attrs={"layout_free_placeholders": [B]},  # enable automatic layout transform for tensor B
    )
    out = te.compute((N, M), lambda i, j: matmul[i, j] + C[i, j], name="out")

    return [A, B, C, out]

# %%
target = tvm.target.Target("llvm")
N = L = M = 1024
task = tvm.auto_scheduler.SearchTask(func=matmul_add, args=(N, L, M, "float32"), target=target)

# Inspect the computational graph
print("Computational DAG:")
print(task.compute_dag)
# Out:
# Computational DAG:
# A = PLACEHOLDER [1024, 1024]
# B = PLACEHOLDER [1024, 1024]
# matmul(i, j) += (A[i, k]*B[k, j])
# C = PLACEHOLDER [1024, 1024]
# out(i, j) = (matmul[i, j] + C[i, j])

# %%
log_file = "matmul.json"
tune_option = auto_scheduler.TuningOptions(
    num_measure_trials=2000,
    measure_callbacks=[auto_scheduler.RecordToFile(log_file)],
    verbose=2,
)

# %%
# Run auto-tuning (search)
task.tune(tune_option)
# Apply the best schedule
sch, args = task.apply_best(log_file)
# Out:
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 2020	fail_ct: 0	Time elapsed: 0.61
# GA Iter: 0	Max score: 0.9991	Min score: 0.9354	#Pop: 128	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 1.0000	Min score: 0.9862	#Pop: 128	#M+: 1378	#M-: 76
# EvolutionarySearch		#s: 128	Time elapsed: 2.59
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 10 programs to measure:
# ..........**********
# ==================================================
# No: 1	GFLOPS: 41.14 / 41.14	results: MeasureResult(cost:[0.0522], error_no:0, all_cost:0.66, Tstamp:1636845770.41)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@j.1@ (0,4)
#   matmul auto_unroll: 64
#   for k.0 (0,32)
#     for i.2 (0,64)
#       for j.2 (0,256)
#         for k.1 (0,32)
#           for i.3 (0,4)
#             vectorize j.3 (0,4)
#               matmul = ...
#   for i.2 (0,256)
#     for j.2 (0,1024)
#       out = ...
#
# ==================================================
# No: 2	GFLOPS: 85.89 / 85.89	results: MeasureResult(cost:[0.0250], error_no:0, all_cost:3.88, Tstamp:1636845770.80)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@j.1@ (0,32)
#   matmul auto_unroll: 16
#   for k.0 (0,1024)
#     for i.2 (0,4)
#       for j.2 (0,8)
#         for i.3 (0,16)
#           for j.3 (0,64)
#             matmul = ...
#   for i.2 (0,64)
#     for j.2 (0,512)
#       out = ...
#
# ==================================================
# No: 3	GFLOPS: 51.29 / 85.89	results: MeasureResult(cost:[0.0419], error_no:0, all_cost:0.51, Tstamp:1636845771.12)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@j.1@ (0,512)
#   for k.0 (0,16)
#     for i.2 (0,64)
#       for k.1 (0,64)
#         for i.3 (0,4)
#           vectorize j.3 (0,8)
#             matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 4	GFLOPS: 71.81 / 85.89	results: MeasureResult(cost:[0.0299], error_no:0, all_cost:1.22, Tstamp:1636845771.51)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,8)
#   matmul auto_unroll: 512
#   for i.1 (0,1024)
#     for j.1 (0,8)
#       for k.0 (0,64)
#         for j.2 (0,4)
#           for k.1 (0,16)
#             vectorize j.3 (0,4)
#               matmul = ...
#   for i.1 (0,1024)
#     vectorize j.1 (0,128)
#       out = ...
#
# ==================================================
# No: 5	GFLOPS: 49.31 / 85.89	results: MeasureResult(cost:[0.0436], error_no:0, all_cost:0.54, Tstamp:1636845771.85)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,512)
#   for i.1 (0,16)
#     for j.1 (0,2)
#       matmul auto_unroll: 512
#       for k.0 (0,1024)
#         for i.2 (0,4)
#           for j.2 (0,4)
#             for i.3 (0,2)
#               vectorize j.3 (0,2)
#                 matmul = ...
#       for i.2 (0,8)
#         vectorize j.2 (0,8)
#           out = ...
#
# ==================================================
# No: 6	GFLOPS: 95.44 / 95.44	results: MeasureResult(cost:[0.0225], error_no:0, all_cost:1.37, Tstamp:1636845772.21)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@ (0,32)
#   for j.1 (0,8)
#     matmul auto_unroll: 64
#     for k.0 (0,256)
#       for i.2 (0,64)
#         for k.1 (0,4)
#           for i.3 (0,2)
#             for j.3 (0,32)
#               matmul = ...
#     for i.2 (0,128)
#       for j.2 (0,32)
#         out = ...
#
# ==================================================
# No: 7	GFLOPS: 71.20 / 95.44	results: MeasureResult(cost:[0.0302], error_no:0, all_cost:1.30, Tstamp:1636845772.62)
# ==================================================
# Placeholder: A, B, C
# parallel i.0 (0,256)
#   for j.0 (0,4)
#     for j.1 (0,32)
#       for k.0 (0,128)
#         for i.2 (0,4)
#           for j.2 (0,8)
#             for k.1 (0,8)
#               matmul = ...
#     for i.1 (0,4)
#       for j.1 (0,256)
#         out = ...
#
# ==================================================
# No: 8	GFLOPS: 71.75 / 95.44	results: MeasureResult(cost:[0.0299], error_no:0, all_cost:0.78, Tstamp:1636845773.01)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,32)
#   for i.1 (0,16)
#     for j.1 (0,2)
#       for k.0 (0,128)
#         for i.2 (0,2)
#           for j.2 (0,64)
#             for k.1 (0,8)
#               for i.3 (0,8)
#                 matmul = ...
#   for i.1 (0,256)
#     for j.1 (0,128)
#       out = ...
#
# ==================================================
# No: 9	GFLOPS: 56.17 / 95.44	results: MeasureResult(cost:[0.0383], error_no:0, all_cost:0.49, Tstamp:1636845773.32)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@ (0,8192)
#   for j.1 (0,4)
#     matmul auto_unroll: 64
#     for k.0 (0,32)
#       for j.2 (0,2)
#         for k.1 (0,32)
#           for i.3 (0,8)
#             vectorize j.3 (0,2)
#               matmul = ...
#     for i.2 (0,8)
#       vectorize j.2 (0,4)
#         out = ...
#
# ==================================================
# No: 10	GFLOPS: 84.21 / 95.44	results: MeasureResult(cost:[0.0255], error_no:0, all_cost:0.78, Tstamp:1636845773.71)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@j.1@ (0,1024)
#   for k.0 (0,64)
#     for i.2 (0,8)
#       for j.2 (0,16)
#         for k.1 (0,16)
#           vectorize j.3 (0,8)
#             matmul = ...
#   for i.2 (0,8)
#     for j.2 (0,128)
#       out = ...
#
# Time elapsed for measurement: 8.44 s
# ----------------------------------------------------------------------
# ------------------------------  [ Done ]
# ----------------------------------------------------------------------

# %%
print("Lowered TIR:")
print(tvm.lower(sch, args, simple_mode=True))
# Out:
# Lowered TIR:
# primfn(A_1: handle, B_1: handle, C_1: handle, out_1: handle) -> ()
#   attr = {"from_legacy_te_schedule": True, "global_symbol": "main", "tir.noalias": True}
#   buffers = {C: Buffer(C_2: Pointer(float32), float32, [1024, 1024], []),
#              A: Buffer(A_2: Pointer(float32), float32, [1024, 1024], []),
#              out: Buffer(out_2: Pointer(float32), float32, [1024, 1024], []),
#              B: Buffer(B_2: Pointer(float32), float32, [1024, 1024], [])}
#   buffer_map = {A_1: A, B_1: B, C_1: C, out_1: out} {
#   allocate(auto_scheduler_layout_transform: Pointer(global float32), float32, [1048576]), storage_scope = global;
#   allocate(matmul: Pointer(global float32), float32, [1048576]), storage_scope = global {
#     for (ax0.ax1.fused.ax2.fused: int32, 0, 512) "parallel" {
#       for (ax3: int32, 0, 4) {
#         for (ax4: int32, 0, 32) {
#           for (ax5: int32, 0, 16) {
#             auto_scheduler_layout_transform[((((ax0.ax1.fused.ax2.fused*2048) + (ax3*512)) + (ax4*16)) + ax5)] = (float32*)B_2[(((((floormod(ax0.ax1.fused.ax2.fused, 32)*32768) + (ax4*1024)) + (floordiv(ax0.ax1.fused.ax2.fused, 32)*64)) + (ax3*16)) + ax5)]
#           }
#         }
#       }
#     }
#     for (i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused: int32, 0, 128) "parallel" {
#       for (j.outer.outer.inner: int32, 0, 8) {
#         matmul[ramp((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 1024), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 2048), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 3072), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 4096), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 5120), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 6144), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 7168), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 16), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 1040), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 2064), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 3088), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 4112), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 5136), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 6160), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 7184), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 32), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 1056), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 2080), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 3104), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 4128), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 5152), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 6176), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 7200), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 48), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 1072), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 2096), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 3120), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 4144), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 5168), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 6192), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 7216), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 8192), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 9216), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 10240), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 11264), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 12288), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 13312), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 14336), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 15360), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 8208), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 9232), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 10256), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 11280), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 12304), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 13328), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 14352), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 15376), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 8224), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 9248), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 10272), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 11296), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 12320), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 13344), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 14368), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 15392), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 8240), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 9264), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 10288), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 11312), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 12336), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 13360), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 14384), 1, 16)] = broadcast(0f32, 16)
#         matmul[ramp(((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + 15408), 1, 16)] = broadcast(0f32, 16)
#         for (k.outer: int32, 0, 32) {
#           for (i.outer.inner: int32, 0, 2) {
#             for (j.outer.inner: int32, 0, 4) {
#               matmul[ramp((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)), 1, 16)] = ((float32x16*)matmul[ramp((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)), 1, 16)] + (broadcast((float32*)A_2[(((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32))], 16)*(float32x16*)auto_scheduler_layout_transform[ramp(((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 1024)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp(((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 2048)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp(((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 3072), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 3072), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 3072)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp(((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 4096), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 4096), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 4096)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp(((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 5120), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 5120), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 5120)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp(((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 6144), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 6144), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 6144)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp(((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 7168), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 7168), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 7168)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp(((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)), 1, 16)]))
#               matmul[ramp((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)), 1, 16)] = ((float32x16*)matmul[ramp((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 1)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 16), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 1025)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 16), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 2049)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 16), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 3072), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 3072), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 3073)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 16), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 4096), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 4096), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 4097)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 16), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 5120), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 5120), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 5121)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 16), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 6144), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 6144), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 6145)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 16), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 7168), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 7168), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 7169)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 16), 1, 16)]))
#               matmul[ramp((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)), 1, 16)] = ((float32x16*)matmul[ramp((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 2)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 32), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 1026)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 32), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 2050)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 32), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 3072), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 3072), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 3074)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 32), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 4096), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 4096), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 4098)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 32), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 5120), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 5120), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 5122)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 32), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 6144), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 6144), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 6146)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 32), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 7168), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 7168), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 7170)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 32), 1, 16)]))
#               matmul[ramp((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)), 1, 16)] = ((float32x16*)matmul[ramp((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 3)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 48), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 1027)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 48), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 2051)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 48), 1, 16)]))
# ...
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 1054)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 480), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 2078)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 480), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 3072), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 3072), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 3102)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 480), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 4096), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 4096), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 4126)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 480), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 5120), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 5120), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 5150)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 480), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 6144), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 6144), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 6174)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 480), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 7168), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 7168), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 7198)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 480), 1, 16)]))
#               matmul[ramp((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)), 1, 16)] = ((float32x16*)matmul[ramp((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 31)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 496), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 1024), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 1055)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 496), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 2048), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 2079)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 496), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 3072), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 3072), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 3103)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 496), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 4096), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 4096), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 4127)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 496), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 5120), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 5120), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 5151)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 496), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 6144), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 6144), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 6175)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 496), 1, 16)]))
#               matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 7168), 1, 16)] = ((float32x16*)matmul[ramp(((((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*512)) + (j.outer.outer.inner*64)) + (j.outer.inner*16)) + 7168), 1, 16)] + (broadcast((float32*)A_2[((((floormod(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*16384) + (i.outer.inner*8192)) + (k.outer*32)) + 7199)], 16)*(float32x16*)auto_scheduler_layout_transform[ramp((((((floordiv(i.outer.outer.outer.j.outer.outer.outer.fused.i.outer.outer.inner.fused, 64)*524288) + (j.outer.outer.inner*65536)) + (k.outer*2048)) + (j.outer.inner*512)) + 496), 1, 16)]))
#             }
#           }
#         }
#       }
#     }
#     for (i: int32, 0, 1024) "parallel" {
#       for (j: int32, 0, 1024) {
#         out_2[((i*1024) + j)] = ((float32*)matmul[((i*1024) + j)] + (float32*)C_2[((i*1024) + j)])
#       }
#     }
#   }
# }

# %%
func = tvm.build(sch, args, target)
a_np = np.random.uniform(size=(N, L)).astype(np.float32)
b_np = np.random.uniform(size=(L, M)).astype(np.float32)
c_np = np.random.uniform(size=(N, M)).astype(np.float32)
out_np = a_np.dot(b_np) + c_np

dev = tvm.cpu()
a_tvm = tvm.nd.array(a_np, device=dev)
b_tvm = tvm.nd.array(b_np, device=dev)
c_tvm = tvm.nd.array(c_np, device=dev)
out_tvm = tvm.nd.empty(out_np.shape, device=dev)
func(a_tvm, b_tvm, c_tvm, out_tvm)

# Check results
np.testing.assert_allclose(out_np, out_tvm.numpy(), rtol=1e-3)

# Evaluate execution time.
evaluator = func.time_evaluator(func.entry_name, dev, min_repeat_ms=500)
print(
    "Execution time of this operator: %.3f ms"
    % (np.median(evaluator(a_tvm, b_tvm, c_tvm, out_tvm).results) * 1000)
)
# Out:
# Execution time of this operator: 20.221 ms
